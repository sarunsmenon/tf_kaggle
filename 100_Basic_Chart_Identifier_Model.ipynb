# %% [markdown]
# <a href="https://colab.research.google.com/github/sarunsmenon/tf_kaggle/blob/sarunsmenon/100_Basic_Chart_Identifier_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Load Libraries

# %%
from tensorflow.keras.applications import * #Efficient Net included here
from tensorflow import keras
from tensorflow.keras import models
from tensorflow.keras import layers
from keras.preprocessing.image import ImageDataGenerator
import os
import shutil
import pandas as pd
from sklearn import model_selection
from tqdm import tqdm
from tensorflow.keras import optimizers
import tensorflow as tf
#Use this to check if the GPU is configured correctly
from tensorflow.python.client import device_lib
import seaborn as sns
import pickle

from sklearn.metrics import multilabel_confusion_matrix
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report

# %% [markdown]
# # Define Variables

# %%
from google.colab import drive
from google.colab import data_table
data_table.enable_dataframe_formatter()
NUMBER_OF_CLASSES=4
#drive.mount('/content/drive/')#,force_remount=True)
folder_path = 'drive/MyDrive/Kaggle/benetech-making-graphs-accessible/train/images_sample'
model_path = 'drive/MyDrive/Kaggle/benetech-making-graphs-accessible/model/'

# %%
batch_size = 32
img_height = 120
img_width = 300
seed=2011
sample_size = 5000
image_size = (img_height, img_width)

# %%
valid_split = 0.3 # keeps 70% of data for training

# %% [markdown]
# # Define Training and Validation dataset

# %%
train_ds,val_ds = tf.keras.utils.image_dataset_from_directory(
                                                  directory=folder_path,
                                                  labels="inferred",
                                                  color_mode = "rgb",
                                                  image_size = (img_height, img_width),
                                                  shuffle = True,
                                                  seed=seed,
                                                  validation_split = valid_split,
                                                  subset="both",
                                                  batch_size= batch_size,
                                                  label_mode='categorical')
# Out:
# Found 6057 files belonging to 4 classes.
# Using 4240 files for training.
# Using 1817 files for validation.

# %%
val_batches = tf.data.experimental.cardinality(val_ds)
test_ds = val_ds.take((2*val_batches) // 3)
val_ds = val_ds.skip((2*val_batches) // 3)
print(val_batches.numpy())

# Prefetching samples in GPU memory helps maximize GPU utilization.
train_ds_pf = train_ds.prefetch(tf.data.AUTOTUNE)
val_ds_pf = val_ds.prefetch(tf.data.AUTOTUNE)
# Out:
# 57

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['bar_chart', 'dot_chart', 'line_chart', 'scatter_chart']

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[np.argmax(labels[i].numpy())])
    plt.axis("off")

# %% [markdown]
# # Data Augmentation

# %%
data_augmentation = tf.keras.Sequential(
  [
    layers.BatchNormalization(),
    layers.RandomTranslation(
                              height_factor=(-0.2, 0.3),
                              width_factor=(-0.2, 0.3),
                              fill_mode='reflect',
                              interpolation='bilinear',
                              seed=seed,
                              fill_value=0.0
                            ),
    layers.RandomFlip("horizontal_and_vertical",
                      input_shape=(img_height,
                                  img_width,
                                  3)),
    layers.RandomRotation(40),
    layers.RandomZoom(0.1)
  ]
)

# %%
train_ds = train_ds.map(
    lambda img, label: (data_augmentation(img), label),
    num_parallel_calls=tf.data.AUTOTUNE,
)
# Prefetching samples in GPU memory helps maximize GPU utilization.
train_ds = train_ds.prefetch(tf.data.AUTOTUNE)
val_ds = val_ds.prefetch(tf.data.AUTOTUNE)

# %% [markdown]
# # Model Build

# %% [markdown]
# ## Efficient net Model build

# %%
conv_base = tf.keras.applications.efficientnet_v2.EfficientNetV2B2(weights="imagenet", include_top=False)
conv_base.trainable = False

model = models.Sequential()
model.add(data_augmentation)
model.add(conv_base)
model.add(layers.GlobalMaxPooling2D(name="gap"))
model.add(layers.Dense(512, activation='relu'))
#avoid overfitting
model.add(layers.Dropout(rate=0.2, name="dropout_out"))
# Set NUMBER_OF_CLASSES to the number of your final predictions.
model.add(layers.Dense(NUMBER_OF_CLASSES, activation="softmax", name="fc_out"))
model.compile(loss='binary_crossentropy',optimizer=optimizers.RMSprop(learning_rate=1e-4),metrics=['acc'])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/efficientnet_v2/efficientnetv2-b2_notop.h5
# 35839040/35839040 [==============================] - 0s 0us/step

# %% [markdown]
# ## Basic Model Build

# %%
model = models.Sequential()

model.add(data_augmentation)

model.add(layers.Conv2D(filters=32,kernel_size=3, activation='relu',input_shape=[img_height,img_width,3]))
model.add(layers.MaxPool2D(pool_size=2, strides=2))

model.add(layers.Conv2D(filters=32,kernel_size=3, activation='relu'))
model.add(layers.MaxPool2D(pool_size=2, strides=2))

model.add(layers.Flatten())

model.add(layers.Dense(units=128, activation='relu'))

model.add(layers.Dense(units=128, activation='relu'))

model.add(layers.Dense(NUMBER_OF_CLASSES, activation="softmax", name="fc_out"))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 118, 298, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 59, 149, 32)      0
#  )
#
#  conv2d_1 (Conv2D)           (None, 57, 147, 32)       9248
#
#  max_pooling2d_1 (MaxPooling  (None, 28, 73, 32)       0
#  2D)
#
#  flatten (Flatten)           (None, 65408)             0
#
#  dense (Dense)               (None, 128)               8372352
#
#  dense_1 (Dense)             (None, 128)               16512
#
#  fc_out (Dense)              (None, 4)                 516
#
# =================================================================
# Total params: 8,399,524
# Trainable params: 8,399,524
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Keras Recommended Model Build - https://keras.io/examples/vision/image_classification_from_scratch/

# %%
def make_model(input_shape, num_classes):

  inputs = keras.Input(shape=input_shape)

  # Entry block
  x = layers.Rescaling(1.0 / 255)(inputs)
  x = layers.Conv2D(128, 3, strides=2, padding="same")(x)
  x = layers.BatchNormalization()(x)
  x = layers.Activation("relu")(x)
  previous_block_activation = x

  for size in [256, 512, 728]:
    x = layers.Activation("relu")(x)
    x = layers.SeparableConv2D(filters = size, kernel_size=3, padding="same")(x)
    x = layers.BatchNormalization()(x)

    x = layers.Activation("relu")(x)
    x = layers.SeparableConv2D(filters = size, kernel_size=3, padding="same")(x)
    x = layers.BatchNormalization()(x)

    x = layers.MaxPooling2D(3, strides=2, padding="same")(x)

    # Project residual
    residual = layers.Conv2D(size, 1, strides=2, padding="same")(previous_block_activation)

    x = layers.add([x, residual])  # Add back residual
    previous_block_activation = x  # Set aside next residual

  x = layers.SeparableConv2D(1024, 3, padding="same",activation='relu')(x)
  x = layers.BatchNormalization()(x)

  x = layers.GlobalAveragePooling2D()(x)
  if num_classes == 2:
      activation = "sigmoid"
      units = 1
  else:
      activation = "softmax"
      units = num_classes

  x = layers.Dropout(0.5)(x)
  outputs = layers.Dense(units, activation=activation)(x)
  return tf.keras.Model(inputs, outputs)


model = make_model(input_shape=image_size + (3,), num_classes=len(class_names))
tf.keras.utils.plot_model(model, show_shapes=True)

# %% [markdown]
# # Train Model

# %%
model.compile(
    loss="categorical_crossentropy",
    optimizer=keras.optimizers.Adam(1e-3),
    metrics=["accuracy"],
)

epochs = 25

callbacks = [
    tf.keras.callbacks.ModelCheckpoint("save_at_{epoch}.keras"),
]

# %%
# %%time

history = model.fit(
  train_ds,
  validation_data=val_ds,
  callbacks=callbacks,
  epochs=epochs
)
# Out:
# Epoch 1/25
# 133/133 [==============================] - 744s 5s/step - loss: 0.8080 - accuracy: 0.6950 - val_loss: 1.7544 - val_accuracy: 0.3977
# Epoch 2/25
# 133/133 [==============================] - 74s 548ms/step - loss: 0.4698 - accuracy: 0.8165 - val_loss: 2.7682 - val_accuracy: 0.3977
# Epoch 3/25
# 133/133 [==============================] - 74s 544ms/step - loss: 0.3651 - accuracy: 0.8604 - val_loss: 2.8903 - val_accuracy: 0.3977
# Epoch 4/25
# 133/133 [==============================] - 73s 544ms/step - loss: 0.2948 - accuracy: 0.8807 - val_loss: 1.7896 - val_accuracy: 0.4143
# Epoch 5/25
# 133/133 [==============================] - 74s 548ms/step - loss: 0.2776 - accuracy: 0.8842 - val_loss: 1.2692 - val_accuracy: 0.5541
# Epoch 6/25
# 133/133 [==============================] - 74s 551ms/step - loss: 0.2690 - accuracy: 0.8903 - val_loss: 0.4402 - val_accuracy: 0.8353
# Epoch 7/25
# 133/133 [==============================] - 73s 544ms/step - loss: 0.2262 - accuracy: 0.9075 - val_loss: 0.6862 - val_accuracy: 0.7188
# Epoch 8/25
# 133/133 [==============================] - 74s 544ms/step - loss: 0.2214 - accuracy: 0.9099 - val_loss: 0.8040 - val_accuracy: 0.6772
# Epoch 9/25
# 133/133 [==============================] - 74s 549ms/step - loss: 0.2174 - accuracy: 0.9132 - val_loss: 0.7925 - val_accuracy: 0.6589
# Epoch 10/25
# 133/133 [==============================] - 73s 542ms/step - loss: 0.1909 - accuracy: 0.9139 - val_loss: 0.5269 - val_accuracy: 0.7671
# Epoch 11/25
# 133/133 [==============================] - 75s 555ms/step - loss: 0.1909 - accuracy: 0.9186 - val_loss: 0.3665 - val_accuracy: 0.8968
# Epoch 12/25
# 133/133 [==============================] - 74s 547ms/step - loss: 0.1858 - accuracy: 0.9184 - val_loss: 0.6896 - val_accuracy: 0.7537
# Epoch 13/25
# 133/133 [==============================] - 73s 543ms/step - loss: 0.1704 - accuracy: 0.9318 - val_loss: 0.5665 - val_accuracy: 0.7105
# Epoch 14/25
# 133/133 [==============================] - 73s 544ms/step - loss: 0.1479 - accuracy: 0.9502 - val_loss: 1.1190 - val_accuracy: 0.5391
# Epoch 15/25
# 133/133 [==============================] - 74s 548ms/step - loss: 0.1305 - accuracy: 0.9559 - val_loss: 1.5327 - val_accuracy: 0.5691
# Epoch 16/25
# 133/133 [==============================] - 73s 543ms/step - loss: 0.1274 - accuracy: 0.9590 - val_loss: 1.6935 - val_accuracy: 0.4908
# Epoch 17/25
# 133/133 [==============================] - 74s 544ms/step - loss: 0.1116 - accuracy: 0.9656 - val_loss: 0.3705 - val_accuracy: 0.8869
# Epoch 18/25
# 133/133 [==============================] - 75s 550ms/step - loss: 0.1161 - accuracy: 0.9590 - val_loss: 1.0349 - val_accuracy: 0.7105
# Epoch 19/25
# 133/133 [==============================] - 74s 549ms/step - loss: 0.0834 - accuracy: 0.9719 - val_loss: 0.7113 - val_accuracy: 0.7438
# Epoch 20/25
# 133/133 [==============================] - 73s 546ms/step - loss: 0.0909 - accuracy: 0.9658 - val_loss: 1.0144 - val_accuracy: 0.7987
# Epoch 21/25
# 133/133 [==============================] - 73s 537ms/step - loss: 0.0845 - accuracy: 0.9726 - val_loss: 0.7524 - val_accuracy: 0.7038
# Epoch 22/25
# 133/133 [==============================] - 73s 538ms/step - loss: 0.0843 - accuracy: 0.9726 - val_loss: 0.5130 - val_accuracy: 0.8236
# Epoch 23/25
# 133/133 [==============================] - 72s 532ms/step - loss: 0.0951 - accuracy: 0.9682 - val_loss: 0.2809 - val_accuracy: 0.8602
# Epoch 24/25
# 133/133 [==============================] - 72s 536ms/step - loss: 0.0690 - accuracy: 0.9771 - val_loss: 0.5389 - val_accuracy: 0.7870
# Epoch 25/25
# 133/133 [==============================] - 73s 537ms/step - loss: 0.0803 - accuracy: 0.9752 - val_loss: 0.3384 - val_accuracy: 0.8669
# CPU times: user 41min 55s, sys: 1min 34s, total: 43min 29s
# Wall time: 43min 48s

# %%
import pickle
file = open(model_path+'Basic_Chart_Identifier_Model_sample_0.2.pkl', 'wb')
pickle.dump(model, file)
file.close()


file = open(model_path+'Basic_Chart_Identifier_Model_sample_0.2_history.pkl', 'wb')
pickle.dump(history, file)
file.close()

# %%
history_dict = history.history

history_metrics = pd.DataFrame({'loss':history_dict['loss'],
                                'accuracy':history_dict['accuracy'],
                                'val_loss':history_dict['val_loss'],
                                'val_accuracy':history_dict['val_accuracy']
                                })

sns.lineplot(data=history_metrics)
# Out:
# <Axes: >

# %% [markdown]
# # Inference

# %%
model = pickle.load(open(model_path+'Basic_Chart_Identifier_Model_sample_0.2.pkl', 'rb'))

# %% [markdown]
# ## Predictions

# %%
predictions = model.predict(test_ds,batch_size=batch_size)
pred_df = pd.DataFrame(predictions)
# Out:
# 38/38 [==============================] - 6s 145ms/step

# %%
max_columns = pred_df.idxmax(axis=1)
pred_df['max_col_name'] = max_columns
pred_df['pred_label'] = pred_df['max_col_name'].apply(lambda index: class_names[index])

# %% [markdown]
# ## True Labels

# %%
labels_lst = []
for images, labels in test_ds:
  labels_lst.append(pd.DataFrame(labels))

# %%
true_labels_df = pd.concat(labels_lst).reset_index(drop=True)
max_columns = true_labels_df.idxmax(axis=1)
true_labels_df['max_col_name'] = max_columns
true_labels_df['true_label'] = true_labels_df['max_col_name'].apply(lambda index: class_names[index])

# %% [markdown]
# # Evaluation

# %%
y_true = true_labels_df['true_label']
y_pred = pred_df['pred_label']

# %%
ConfusionMatrixDisplay.from_predictions(
    y_true, y_pred, labels=class_names
)

# %%
print(classification_report(y_true, y_pred, target_names=class_names))
# Out:
#                precision    recall  f1-score   support
#
#     bar_chart       1.00      0.91      0.95       398
#     dot_chart       1.00      0.99      0.99        88
#    line_chart       0.77      1.00      0.87       519
# scatter_chart       1.00      0.42      0.59       211
#
#      accuracy                           0.87      1216
#     macro avg       0.94      0.83      0.85      1216
#  weighted avg       0.90      0.87      0.86      1216

# %% [markdown]
# # Inference on one image

# %%
img = keras.utils.load_img('drive/MyDrive/Kaggle/benetech-making-graphs-accessible/train/images/bar_chart/0a5b952cfbdf.jpg', target_size=image_size)
img_array = keras.utils.img_to_array(img)
img_array = tf.expand_dims(img_array, 0)  # Create batch axis

img_predictions = model.predict(img_array)
# Out:
# 1/1 [==============================] - 1s 667ms/step

# %%
pred_label = class_names[np.argmax(np.round(img_predictions,2))]
print(" Predicted label is :: "+ pred_label)
# Out:
#  Predicted label is :: bar_chart

# %%
plt.imshow(img)
