# %% [markdown]
# <a href="https://colab.research.google.com/github/sarunsmenon/tf_kaggle/blob/sarunsmenon/004_unzip.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import json
import pandas as pd
import numpy as np

# %%
full_folder_path = 'drive/MyDrive/Kaggle/'

# %%
import zipfile
with zipfile.ZipFile('drive/MyDrive/Kaggle/benetech-making-graphs-accessible.zip', 'r') as zip_ref:
    zip_ref.extractall('drive/MyDrive/Kaggle/test/')
